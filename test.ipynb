# %%
import geometer_jax as gx

p = gx.Point(2, 4)
q = gx.Point(3, 5)
l = gx.Line(p, q)
m = gx.Line(0, 1, 0)
# Out:
# c:\Users\skand\miniconda3\envs\py313\Lib\site-packages\jax\_src\ops\scatter.py:103: FutureWarning: scatter inputs have incompatible types: cannot safely cast value from dtype=int32 to dtype=int8 with jax_numpy_dtype_promotion=standard. In future JAX releases this will result in an error.
#   warnings.warn(
